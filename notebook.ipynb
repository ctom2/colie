# %%
# !git clone https://github.com/ctom2/colie
# Out:
# Cloning into 'colie'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 39 (delta 11), reused 22 (delta 2), pack-reused 0
# Receiving objects: 100% (39/39), 15.87 MiB | 18.57 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !cd colie; python colie.py --input_folder 'input' --alpha 1 --beta 20 --gamma 8 --delta 5 --L 0.3
# Out:
#  > running
# 100% 1/1 [00:05<00:00,  5.17s/it]
#  > reconstruction done

# %%
import matplotlib.pyplot as plt
from PIL import Image

input_image  = Image.open('colie/input/5642.png')
output_image = Image.open('colie/output/5642.png')

plt.figure(figsize=(15, 8))
plt.subplot(121)
plt.imshow(input_image)
plt.title('input image')
plt.subplot(122)
plt.imshow(output_image)
plt.title('output image')
plt.show()
